# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup

# %%
url = 'http://m.facilito.gob.pe/facilito-mobile/pages/public/buscarCombustible?idsCombustible=74&idsCombustible=78&idsCombustible=73&idsCombustible=03&idsCombustible=72&idsCombustible=04&masCercano=0&usarMiUbicacion=0&area=8&miLatitud=-12.089684&miLongitud=-77.033528&distrito=150136&provincia=150100&departamento=150000&distritoText=SAN%20MIGUEL&provinciaText=LIMA&departamentoText=LIMA&codigoUnidad=&startIndex=0&recordsPerPage=200&back=0'
response = requests.get(url)

# %%
response
soup = BeautifulSoup(response.text, "html.parser")
soup.findAll('td')
# Out:
# [<td class="linea texto_3 manito" onclick="cargarUnidad(19957)">S/.12.64</td>,
#  <td class="linea texto_1 manito" onclick="cargarUnidad(19957)" width="100%">
#                                          EXPLORIUM S.A.C.<br/>
#                                          AV. VENEZUELA N° 1829 INTERSECCION AV. TINGO MARIA (Distancia: 4.38 Km)<br/>
#  <span class="texto_2">GASOHOL 98 PLUS
#
#
#                                                  <br/>
#  </span>
#  </td>,
#  <td class="linea manito" onclick="cargarUnidad(19957); return false;"><img alt="Ver detalle" src="/facilito-mobile/images/icons/view_detailed.png;jsessionid=B512566CC1F5FE08E10DF1412D0398D6"/></td>,
#  <td class="linea manito" onclick="ubicarEnMapa(19957, -12.06, -77.06); return false;"><img alt="Ver Mapa" src="/facilito-mobile/images/icons/map.png;jsessionid=B512566CC1F5FE08E10DF1412D0398D6"/></td>,
#  <td class="linea texto_3 manito" onclick="cargarUnidad(7010)">S/.13.89</td>,
# ...
